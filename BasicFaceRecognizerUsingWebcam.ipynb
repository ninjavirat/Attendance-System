# %% [markdown]
# # Basic face recognizer using pre trained model
#
# Below the is the implementation of a very basic face recognizer which can identify the face of the person showing on a web cam.
# The implementation is inspired by two path breaking papers on facial recognition using deep convoluted neural network, namely FaceNet and DeepFace.
#
# I have used pre trained model Keras-OpenFace which is an open source Keras implementation of the OpenFace (Originally Torch implemented)
#
# The pretrained model that I have used is by Victor Sy Wang's implementation and was loaded using his code: https://github.com/iwantooxxoox/Keras-OpenFace.

# %% [markdown]
# # Import the prerequisite libraries
#
# We will be importing utils.py from https://github.com/iwantooxxoox/Keras-OpenFace/blob/master/utils.py (available with code) which contains utility functions to create the neural network and load the weights assoiated with it.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.models import Model
from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D, AveragePooling2D
from keras.layers.merge import Concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.engine.topology import Layer
from keras import backend as K
import cv2
import os
import numpy as np
from numpy import genfromtxt
import pandas as pd
import tensorflow as tf
from utils import LRN2D
import utils

# %load_ext autoreload
# %autoreload 2

np.set_printoptions(threshold=np.nan)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Contructing the neural network model
# The model here constructed is based on FaceNet's Inception model.
#
# The implementation of model is available at: https://github.com/iwantooxxoox/Keras-OpenFace

# %%
myInput = Input(shape=(96, 96, 3))

x = ZeroPadding2D(padding=(3, 3), input_shape=(96, 96, 3))(myInput)
x = Conv2D(64, (7, 7), strides=(2, 2), name='conv1')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn1')(x)
x = Activation('relu')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = MaxPooling2D(pool_size=3, strides=2)(x)
x = Lambda(LRN2D, name='lrn_1')(x)
x = Conv2D(64, (1, 1), name='conv2')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn2')(x)
x = Activation('relu')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = Conv2D(192, (3, 3), name='conv3')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn3')(x)
x = Activation('relu')(x)
x = Lambda(LRN2D, name='lrn_2')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = MaxPooling2D(pool_size=3, strides=2)(x)

# Inception3a
inception_3a_3x3 = Conv2D(96, (1, 1), name='inception_3a_3x3_conv1')(x)
inception_3a_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_3x3_bn1')(inception_3a_3x3)
inception_3a_3x3 = Activation('relu')(inception_3a_3x3)
inception_3a_3x3 = ZeroPadding2D(padding=(1, 1))(inception_3a_3x3)
inception_3a_3x3 = Conv2D(128, (3, 3), name='inception_3a_3x3_conv2')(inception_3a_3x3)
inception_3a_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_3x3_bn2')(inception_3a_3x3)
inception_3a_3x3 = Activation('relu')(inception_3a_3x3)

inception_3a_5x5 = Conv2D(16, (1, 1), name='inception_3a_5x5_conv1')(x)
inception_3a_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_5x5_bn1')(inception_3a_5x5)
inception_3a_5x5 = Activation('relu')(inception_3a_5x5)
inception_3a_5x5 = ZeroPadding2D(padding=(2, 2))(inception_3a_5x5)
inception_3a_5x5 = Conv2D(32, (5, 5), name='inception_3a_5x5_conv2')(inception_3a_5x5)
inception_3a_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_5x5_bn2')(inception_3a_5x5)
inception_3a_5x5 = Activation('relu')(inception_3a_5x5)

inception_3a_pool = MaxPooling2D(pool_size=3, strides=2)(x)
inception_3a_pool = Conv2D(32, (1, 1), name='inception_3a_pool_conv')(inception_3a_pool)
inception_3a_pool = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_pool_bn')(inception_3a_pool)
inception_3a_pool = Activation('relu')(inception_3a_pool)
inception_3a_pool = ZeroPadding2D(padding=((3, 4), (3, 4)))(inception_3a_pool)

inception_3a_1x1 = Conv2D(64, (1, 1), name='inception_3a_1x1_conv')(x)
inception_3a_1x1 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_1x1_bn')(inception_3a_1x1)
inception_3a_1x1 = Activation('relu')(inception_3a_1x1)

inception_3a = concatenate([inception_3a_3x3, inception_3a_5x5, inception_3a_pool, inception_3a_1x1], axis=3)

# Inception3b
inception_3b_3x3 = Conv2D(96, (1, 1), name='inception_3b_3x3_conv1')(inception_3a)
inception_3b_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_3x3_bn1')(inception_3b_3x3)
inception_3b_3x3 = Activation('relu')(inception_3b_3x3)
inception_3b_3x3 = ZeroPadding2D(padding=(1, 1))(inception_3b_3x3)
inception_3b_3x3 = Conv2D(128, (3, 3), name='inception_3b_3x3_conv2')(inception_3b_3x3)
inception_3b_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_3x3_bn2')(inception_3b_3x3)
inception_3b_3x3 = Activation('relu')(inception_3b_3x3)

inception_3b_5x5 = Conv2D(32, (1, 1), name='inception_3b_5x5_conv1')(inception_3a)
inception_3b_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_5x5_bn1')(inception_3b_5x5)
inception_3b_5x5 = Activation('relu')(inception_3b_5x5)
inception_3b_5x5 = ZeroPadding2D(padding=(2, 2))(inception_3b_5x5)
inception_3b_5x5 = Conv2D(64, (5, 5), name='inception_3b_5x5_conv2')(inception_3b_5x5)
inception_3b_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_5x5_bn2')(inception_3b_5x5)
inception_3b_5x5 = Activation('relu')(inception_3b_5x5)

inception_3b_pool = Lambda(lambda x: x**2, name='power2_3b')(inception_3a)
inception_3b_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_3b_pool)
inception_3b_pool = Lambda(lambda x: x*9, name='mult9_3b')(inception_3b_pool)
inception_3b_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_3b')(inception_3b_pool)
inception_3b_pool = Conv2D(64, (1, 1), name='inception_3b_pool_conv')(inception_3b_pool)
inception_3b_pool = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_pool_bn')(inception_3b_pool)
inception_3b_pool = Activation('relu')(inception_3b_pool)
inception_3b_pool = ZeroPadding2D(padding=(4, 4))(inception_3b_pool)

inception_3b_1x1 = Conv2D(64, (1, 1), name='inception_3b_1x1_conv')(inception_3a)
inception_3b_1x1 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_1x1_bn')(inception_3b_1x1)
inception_3b_1x1 = Activation('relu')(inception_3b_1x1)

inception_3b = concatenate([inception_3b_3x3, inception_3b_5x5, inception_3b_pool, inception_3b_1x1], axis=3)

# Inception3c
inception_3c_3x3 = utils.conv2d_bn(inception_3b,
                                   layer='inception_3c_3x3',
                                   cv1_out=128,
                                   cv1_filter=(1, 1),
                                   cv2_out=256,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(2, 2),
                                   padding=(1, 1))

inception_3c_5x5 = utils.conv2d_bn(inception_3b,
                                   layer='inception_3c_5x5',
                                   cv1_out=32,
                                   cv1_filter=(1, 1),
                                   cv2_out=64,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(2, 2),
                                   padding=(2, 2))

inception_3c_pool = MaxPooling2D(pool_size=3, strides=2)(inception_3b)
inception_3c_pool = ZeroPadding2D(padding=((0, 1), (0, 1)))(inception_3c_pool)

inception_3c = concatenate([inception_3c_3x3, inception_3c_5x5, inception_3c_pool], axis=3)

#inception 4a
inception_4a_3x3 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=192,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))
inception_4a_5x5 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_5x5',
                                   cv1_out=32,
                                   cv1_filter=(1, 1),
                                   cv2_out=64,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(1, 1),
                                   padding=(2, 2))

inception_4a_pool = Lambda(lambda x: x**2, name='power2_4a')(inception_3c)
inception_4a_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_4a_pool)
inception_4a_pool = Lambda(lambda x: x*9, name='mult9_4a')(inception_4a_pool)
inception_4a_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_4a')(inception_4a_pool)
inception_4a_pool = utils.conv2d_bn(inception_4a_pool,
                                   layer='inception_4a_pool',
                                   cv1_out=128,
                                   cv1_filter=(1, 1),
                                   padding=(2, 2))
inception_4a_1x1 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))
inception_4a = concatenate([inception_4a_3x3, inception_4a_5x5, inception_4a_pool, inception_4a_1x1], axis=3)

#inception4e
inception_4e_3x3 = utils.conv2d_bn(inception_4a,
                                   layer='inception_4e_3x3',
                                   cv1_out=160,
                                   cv1_filter=(1, 1),
                                   cv2_out=256,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(2, 2),
                                   padding=(1, 1))
inception_4e_5x5 = utils.conv2d_bn(inception_4a,
                                   layer='inception_4e_5x5',
                                   cv1_out=64,
                                   cv1_filter=(1, 1),
                                   cv2_out=128,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(2, 2),
                                   padding=(2, 2))
inception_4e_pool = MaxPooling2D(pool_size=3, strides=2)(inception_4a)
inception_4e_pool = ZeroPadding2D(padding=((0, 1), (0, 1)))(inception_4e_pool)

inception_4e = concatenate([inception_4e_3x3, inception_4e_5x5, inception_4e_pool], axis=3)

#inception5a
inception_5a_3x3 = utils.conv2d_bn(inception_4e,
                                   layer='inception_5a_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=384,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))

inception_5a_pool = Lambda(lambda x: x**2, name='power2_5a')(inception_4e)
inception_5a_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_5a_pool)
inception_5a_pool = Lambda(lambda x: x*9, name='mult9_5a')(inception_5a_pool)
inception_5a_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_5a')(inception_5a_pool)
inception_5a_pool = utils.conv2d_bn(inception_5a_pool,
                                   layer='inception_5a_pool',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   padding=(1, 1))
inception_5a_1x1 = utils.conv2d_bn(inception_4e,
                                   layer='inception_5a_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))

inception_5a = concatenate([inception_5a_3x3, inception_5a_pool, inception_5a_1x1], axis=3)

#inception_5b
inception_5b_3x3 = utils.conv2d_bn(inception_5a,
                                   layer='inception_5b_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=384,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))
inception_5b_pool = MaxPooling2D(pool_size=3, strides=2)(inception_5a)
inception_5b_pool = utils.conv2d_bn(inception_5b_pool,
                                   layer='inception_5b_pool',
                                   cv1_out=96,
                                   cv1_filter=(1, 1))
inception_5b_pool = ZeroPadding2D(padding=(1, 1))(inception_5b_pool)

inception_5b_1x1 = utils.conv2d_bn(inception_5a,
                                   layer='inception_5b_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))
inception_5b = concatenate([inception_5b_3x3, inception_5b_pool, inception_5b_1x1], axis=3)

av_pool = AveragePooling2D(pool_size=(3, 3), strides=(1, 1))(inception_5b)
reshape_layer = Flatten()(av_pool)
dense_layer = Dense(128, name='dense_layer')(reshape_layer)
norm_layer = Lambda(lambda  x: K.l2_normalize(x, axis=1), name='norm_layer')(dense_layer)


# Final Model
model = Model(inputs=[myInput], outputs=norm_layer)

# %% [markdown]
# # Loading the model with pretrained weights
#
# FaceNet is trained by minimizing the triplet loss. I will be  loading a previously trained model. weights are avaiable at https://github.com/iwantooxxoox/Keras-OpenFace in the "weights" folder which is also provided in this source.
#
# This can take a couple of minutes to execute and depends on the speed of your machine.

# %%
# Load weights from csv files (which was exported from Openface torch model)
weights = utils.weights
weights_dict = utils.load_weights()

# Set layer weights of the model
for name in weights:
  if model.get_layer(name) != None:
    model.get_layer(name).set_weights(weights_dict[name])
  elif model.get_layer(name) != None:
    model.get_layer(name).set_weights(weights_dict[name])

# %% [markdown]
# ## About <font color=blue>image_to_embedding</font> function
# When the model is loaded with pre trained weights, then we can create the **128 dimensional embedding vectors** for all the face images stored in the "images" folder. **"image_to_embedding"** function pass an image to the Inception network to generate the embedding vector.

# %%
def image_to_embedding(image, model):
    #image = cv2.resize(image, (96, 96), interpolation=cv2.INTER_AREA) 
    image = cv2.resize(image, (96, 96)) 
    img = image[...,::-1]
    img = np.around(np.transpose(img, (0,1,2))/255.0, decimals=12)
    x_train = np.array([img])
    embedding = model.predict_on_batch(x_train)
    return embedding

# %% [markdown]
# ## About <font color=blue>recognize_face</font> function
# This function calculate similarity between the captured image and the images that are already been stored. It passes the image to the trained neural network to generate its embedding vector. Which is then compared with all the embedding vectors of the images stored by calculating L2 Euclidean distance.
#
# If the minimum L2 distance between two embeddings is less than a threshpld (here I have taken the threashhold as .68 (which can be adjusted) then we have a match.

# %%
def recognize_face(face_image, input_embeddings, model):

    embedding = image_to_embedding(face_image, model)
    
    minimum_distance = 200
    name = None
    
    # Loop over  names and encodings.
    for (input_name, input_embedding) in input_embeddings.items():
        
       
        euclidean_distance = np.linalg.norm(embedding-input_embedding)
        

        print('Euclidean distance from %s is %s' %(input_name, euclidean_distance))

        
        if euclidean_distance < minimum_distance:
            minimum_distance = euclidean_distance
            name = input_name
    
    if minimum_distance < 0.68:
        return str(name)
    else:
        return None

# %% [markdown]
# ## About <font color=blue>create_input_image_embeddings</font> function
# This function generates 128 dimensional image ebeddings of all the images stored in the "images" directory by feed forwarding the images to a trained neural network. It creates a dictionary with key as the name of the face and value as embedding
#
#
# ## About <font color=blue>recognize_faces_in_cam</font> function
# This function capture image from the webcam, detect a face in it and crop the image to have a face only, which is then passed to recognize_face function.

# %%
import glob

def create_input_image_embeddings():
    input_embeddings = {}

    for file in glob.glob("images/*"):
        person_name = os.path.splitext(os.path.basename(file))[0]
        image_file = cv2.imread(file, 1)
        input_embeddings[person_name] = image_to_embedding(image_file, model)

    return input_embeddings

def recognize_faces_in_cam(input_embeddings):
    

    cv2.namedWindow("Face Recognizer")
    vc = cv2.VideoCapture(0)
   

    font = cv2.FONT_HERSHEY_SIMPLEX
    face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    
    
    while vc.isOpened():
        _, frame = vc.read()
        img = frame
        height, width, channels = frame.shape

        
        
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)

        # Loop through all the faces detected 
        identities = []
        for (x, y, w, h) in faces:
            x1 = x
            y1 = y
            x2 = x+w
            y2 = y+h

           
            
            face_image = frame[max(0, y1):min(height, y2), max(0, x1):min(width, x2)]    
            identity = recognize_face(face_image, input_embeddings, model)
            
            

            if identity is not None:
                img = cv2.rectangle(frame,(x1, y1),(x2, y2),(255,255,255),2)
                cv2.putText(img, str(identity), (x1+5,y1-5), font, 1, (255,255,255), 2)
        
        key = cv2.waitKey(100)
        cv2.imshow("Face Recognizer", img)

        if key == 27: # exit on ESC
            break
    vc.release()
    cv2.destroyAllWindows()

# %% [markdown]
# Capturing the face image
# Following code captures 10 face images of the person. They all are stored in **"images"** folder with the name User_1 to User_10. Select a good captured image from the set of 10 images. Rename it with the name of person and delete rest of them. This image will be used for recognizing the the identity of the person using one shot learning.

# %%
# cam = cv2.VideoCapture(0)
cam = cv2.VideoCapture('https://192.168.0.11:80')#/video
face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
count = 0
while(True):
    ret, img = cam.read()
    #gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_detector.detectMultiScale(img, 1.3, 5)
    for (x,y,w,h) in faces:
        x1 = x
        y1 = y
        x2 = x+w
        y2 = y+h
        cv2.rectangle(img, (x1,y1), (x2,y2), (255,255,255), 2)     
        count += 1
        # Save the captured image into the datasets folder
        cv2.imwrite("images/User_" + str(count) + ".jpg", img[y1:y2,x1:x2])
        cv2.imshow('image', img)
    k = cv2.waitKey(200) & 0xff # Press 'ESC' for exiting video
    if k == 27:
        break
    elif count >= 10: # Take 30 face sample and stop video
         break
cam.release()
cv2.destroyAllWindows()

# %%
import sqlite3
import cv2
import numpy as np

cam = cv2.VideoCapture(0)
#cam = cv2.VideoCapture('http://172.16.2.167:8080/video') #taking the image through the webcam

face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
def insertOrUpdate(Id,Name,Regno):
    conn = sqlite3.connect("Container.db")
    cmd = "SELECT * FROM Identity WHERE ID="+str(Id)
    cursor = conn.execute(cmd)
    isRecordExist = 0
    for row in cursor:
        isRecordExist=1 
    if(isRecordExist==1):
        cmd = "UPDATE Identity SET Name=' "+str(Name)+" ' WHERE ID="+str(Id)
        cmd = "UPDATE Identity SET Regno=' "+str(Regno)+" ' WHERE ID="+str(Id)
    else:
        cmd ="INSERT INTO Identity(ID,Name,Regno) Values("+str(Id)+",' "+str(Name)+" ',' "+str(Regno)+" ')"  
    conn.execute(cmd)
    conn.commit()
    conn.close()

Id = input("enter your id : ")
name = input("Enter Your Name : ")
reg =input("Enter Your Registration Number : ")

insertOrUpdate(Id, name,reg)


count = 0
while(True):
    ret, img = cam.read()
    
    #gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    #general Intuition to detect the faces.
    
    faces = face_detector.detectMultiScale(img, 1.3, 5)
    for (x,y,w,h) in faces:
        x1 = x
        y1 = y
        x2 = x+w
        y2 = y+h
        cv2.rectangle(img, (x1,y1), (x2,y2), (255,255,255), 2)     
        count += 1
        # Save the captured image into the datasets folder
        #cv2.imwrite("images/User_" + str(count) + ".jpg", img[y1:y2,x1:x2])
        cv2.imwrite("images/" +  name  +"." +str(Id )+'.'+ str(count) + ".jpg", img[y1:y2,x1:x2])
        cv2.imshow('image+window', img)
        cv2.namedWindow("image_window", cv2.WINDOW_NORMAL)
    k = cv2.waitKey(200) & 0xff # Press 'ESC' for exiting video to terminate the webcam.
    if k == 27:
        break
    elif count >= 10: # Take 30 face sample and stop video
         break
cam.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Lets run the face recognizer program :-)

# %%
input_embeddings = create_input_image_embeddings()
recognize_faces_in_cam(input_embeddings)
# Out:
# Euclidean distance from vishnupriya.4.7 is 0.523539
# Euclidean distance from vishnupriya.4.8 is 0.40036705
# Euclidean distance from vishnupriya.4.3 is 0.6718503
# Euclidean distance from vishnupriya.4.4 is 0.59016
# Euclidean distance from vishnupriya.4.5 is 0.50643545
# Euclidean distance from vishnupriya.4.9 is 0.52709424
# Euclidean distance from vishnupriya.4.6 is 0.42471352
# Euclidean distance from vishnupriya.4.1 is 0.4962224
# Euclidean distance from vishnupriya.4.2 is 0.67591554
# Euclidean distance from vishnupriya.4.10 is 0.48870054
# Euclidean distance from vishnupriya.4.7 is 0.4917002
# Euclidean distance from vishnupriya.4.8 is 0.4837953
# Euclidean distance from vishnupriya.4.3 is 0.70622903
# Euclidean distance from vishnupriya.4.4 is 0.6685224
# Euclidean distance from vishnupriya.4.5 is 0.5345419
# Euclidean distance from vishnupriya.4.9 is 0.56732875
# Euclidean distance from vishnupriya.4.6 is 0.3804376
# Euclidean distance from vishnupriya.4.1 is 0.5630574
# Euclidean distance from vishnupriya.4.2 is 0.6561969
# Euclidean distance from vishnupriya.4.10 is 0.5409686
# Euclidean distance from vishnupriya.4.7 is 0.4352661
# Euclidean distance from vishnupriya.4.8 is 0.4182619
# Euclidean distance from vishnupriya.4.3 is 0.6590019
# Euclidean distance from vishnupriya.4.4 is 0.62269413
# Euclidean distance from vishnupriya.4.5 is 0.4834759
# Euclidean distance from vishnupriya.4.9 is 0.48819137
# Euclidean distance from vishnupriya.4.6 is 0.35874042
# Euclidean distance from vishnupriya.4.1 is 0.4848806
# Euclidean distance from vishnupriya.4.2 is 0.6239403
# Euclidean distance from vishnupriya.4.10 is 0.44974354
# Euclidean distance from vishnupriya.4.7 is 0.5326962
# Euclidean distance from vishnupriya.4.8 is 0.38699952
# Euclidean distance from vishnupriya.4.3 is 0.65810263
# Euclidean distance from vishnupriya.4.4 is 0.5414055
# Euclidean distance from vishnupriya.4.5 is 0.45958644
# Euclidean distance from vishnupriya.4.9 is 0.581396
# Euclidean distance from vishnupriya.4.6 is 0.38905057
# Euclidean distance from vishnupriya.4.1 is 0.47102275
# Euclidean distance from vishnupriya.4.2 is 0.6425096
# Euclidean distance from vishnupriya.4.10 is 0.56144416
# Euclidean distance from vishnupriya.4.7 is 0.45241138
# Euclidean distance from vishnupriya.4.8 is 0.3906027
# Euclidean distance from vishnupriya.4.3 is 0.64259607
# Euclidean distance from vishnupriya.4.4 is 0.5787319
# Euclidean distance from vishnupriya.4.5 is 0.4490688
# Euclidean distance from vishnupriya.4.9 is 0.48595816
# Euclidean distance from vishnupriya.4.6 is 0.34366366
# Euclidean distance from vishnupriya.4.1 is 0.49365512
# Euclidean distance from vishnupriya.4.2 is 0.5941232
# Euclidean distance from vishnupriya.4.10 is 0.48254824
# Euclidean distance from vishnupriya.4.7 is 0.55326617
# Euclidean distance from vishnupriya.4.8 is 0.36484063
# Euclidean distance from vishnupriya.4.3 is 0.65471315
# Euclidean distance from vishnupriya.4.4 is 0.534511
# Euclidean distance from vishnupriya.4.5 is 0.46097845
# Euclidean distance from vishnupriya.4.9 is 0.5702335
# Euclidean distance from vishnupriya.4.6 is 0.3882548
# Euclidean distance from vishnupriya.4.1 is 0.47531846
# Euclidean distance from vishnupriya.4.2 is 0.62645483
# Euclidean distance from vishnupriya.4.10 is 0.55737305
# Euclidean distance from vishnupriya.4.7 is 0.49754405
# Euclidean distance from vishnupriya.4.8 is 0.36182284
# Euclidean distance from vishnupriya.4.3 is 0.6356541
# Euclidean distance from vishnupriya.4.4 is 0.54777336
# Euclidean distance from vishnupriya.4.5 is 0.4671411
# Euclidean distance from vishnupriya.4.9 is 0.48581994
# Euclidean distance from vishnupriya.4.6 is 0.42125776
# Euclidean distance from vishnupriya.4.1 is 0.43943694
# Euclidean distance from vishnupriya.4.2 is 0.6211746
# Euclidean distance from vishnupriya.4.10 is 0.4716326
# Euclidean distance from vishnupriya.4.7 is 0.51597595
# Euclidean distance from vishnupriya.4.8 is 0.38086376
# Euclidean distance from vishnupriya.4.3 is 0.5329416
# Euclidean distance from vishnupriya.4.4 is 0.5577422
# Euclidean distance from vishnupriya.4.5 is 0.42936635
# Euclidean distance from vishnupriya.4.9 is 0.48317853
# Euclidean distance from vishnupriya.4.6 is 0.5207161
# Euclidean distance from vishnupriya.4.1 is 0.47853932
# Euclidean distance from vishnupriya.4.2 is 0.4571934
# Euclidean distance from vishnupriya.4.10 is 0.5455043
# Euclidean distance from vishnupriya.4.7 is 0.54645413
# Euclidean distance from vishnupriya.4.8 is 0.30132416
# Euclidean distance from vishnupriya.4.3 is 0.5621579
# Euclidean distance from vishnupriya.4.4 is 0.49724486
# Euclidean distance from vishnupriya.4.5 is 0.41169786
# Euclidean distance from vishnupriya.4.9 is 0.5580232
# Euclidean distance from vishnupriya.4.6 is 0.4313758
# Euclidean distance from vishnupriya.4.1 is 0.43878502
# Euclidean distance from vishnupriya.4.2 is 0.52095544
# Euclidean distance from vishnupriya.4.10 is 0.5631903
# Euclidean distance from vishnupriya.4.7 is 0.59509337
# Euclidean distance from vishnupriya.4.8 is 0.38332495
# Euclidean distance from vishnupriya.4.3 is 0.474521
# Euclidean distance from vishnupriya.4.4 is 0.50200343
# Euclidean distance from vishnupriya.4.5 is 0.3865431
# Euclidean distance from vishnupriya.4.9 is 0.5867786
# Euclidean distance from vishnupriya.4.6 is 0.5693701
# Euclidean distance from vishnupriya.4.1 is 0.4670878
# Euclidean distance from vishnupriya.4.2 is 0.40997797
# Euclidean distance from vishnupriya.4.10 is 0.6629213
# Euclidean distance from vishnupriya.4.7 is 0.46638453
# Euclidean distance from vishnupriya.4.8 is 0.49011892
# Euclidean distance from vishnupriya.4.3 is 0.6466335
# Euclidean distance from vishnupriya.4.4 is 0.65308523
# Euclidean distance from vishnupriya.4.5 is 0.50411206
# Euclidean distance from vishnupriya.4.9 is 0.43992376
# Euclidean distance from vishnupriya.4.6 is 0.4351887
# Euclidean distance from vishnupriya.4.1 is 0.5616477
# Euclidean distance from vishnupriya.4.2 is 0.59842706
# Euclidean distance from vishnupriya.4.10 is 0.49468228
# Euclidean distance from vishnupriya.4.7 is 0.5829417
# Euclidean distance from vishnupriya.4.8 is 0.3831931
# Euclidean distance from vishnupriya.4.3 is 0.6448116
# Euclidean distance from vishnupriya.4.4 is 0.55247056
# Euclidean distance from vishnupriya.4.5 is 0.4849346
# Euclidean distance from vishnupriya.4.9 is 0.5835575
# Euclidean distance from vishnupriya.4.6 is 0.42650038
# Euclidean distance from vishnupriya.4.1 is 0.5066548
# Euclidean distance from vishnupriya.4.2 is 0.6364661
# Euclidean distance from vishnupriya.4.10 is 0.56073165
# Euclidean distance from vishnupriya.4.7 is 0.59177756
# Euclidean distance from vishnupriya.4.8 is 0.3986315
# Euclidean distance from vishnupriya.4.3 is 0.5909694
# Euclidean distance from vishnupriya.4.4 is 0.57101727
# Euclidean distance from vishnupriya.4.5 is 0.46463367
# Euclidean distance from vishnupriya.4.9 is 0.587069
# Euclidean distance from vishnupriya.4.6 is 0.5421692
# Euclidean distance from vishnupriya.4.1 is 0.52809083
# Euclidean distance from vishnupriya.4.2 is 0.5029405
# Euclidean distance from vishnupriya.4.10 is 0.64404756
# Euclidean distance from vishnupriya.4.7 is 0.41627187
# Euclidean distance from vishnupriya.4.8 is 0.512522
# Euclidean distance from vishnupriya.4.3 is 0.6521376
# Euclidean distance from vishnupriya.4.4 is 0.6990522
# Euclidean distance from vishnupriya.4.5 is 0.51950306
# Euclidean distance from vishnupriya.4.9 is 0.37053937
# Euclidean distance from vishnupriya.4.6 is 0.5324606
# Euclidean distance from vishnupriya.4.1 is 0.58639973
# Euclidean distance from vishnupriya.4.2 is 0.6041247
# Euclidean distance from vishnupriya.4.10 is 0.45745996
# Euclidean distance from vishnupriya.4.7 is 0.37622023
# Euclidean distance from vishnupriya.4.8 is 0.54531527
# Euclidean distance from vishnupriya.4.3 is 0.7038291
# Euclidean distance from vishnupriya.4.4 is 0.7491351
# Euclidean distance from vishnupriya.4.5 is 0.5780973
# Euclidean distance from vishnupriya.4.9 is 0.3402023
# Euclidean distance from vishnupriya.4.6 is 0.48584723
# Euclidean distance from vishnupriya.4.1 is 0.61924434
# Euclidean distance from vishnupriya.4.2 is 0.64066386
# Euclidean distance from vishnupriya.4.10 is 0.34738684
# Euclidean distance from vishnupriya.4.7 is 0.49715948
# Euclidean distance from vishnupriya.4.8 is 0.6275998
# Euclidean distance from vishnupriya.4.3 is 0.73610795
# Euclidean distance from vishnupriya.4.4 is 0.79805905
# Euclidean distance from vishnupriya.4.5 is 0.6289669
# Euclidean distance from vishnupriya.4.9 is 0.41105103
# Euclidean distance from vishnupriya.4.6 is 0.5204307
# Euclidean distance from vishnupriya.4.1 is 0.6815637
# Euclidean distance from vishnupriya.4.2 is 0.70350504
# Euclidean distance from vishnupriya.4.10 is 0.4133471
# Euclidean distance from vishnupriya.4.7 is 0.8336524
# Euclidean distance from vishnupriya.4.8 is 0.7352807
# Euclidean distance from vishnupriya.4.3 is 0.8127395
# Euclidean distance from vishnupriya.4.4 is 0.7771417
# Euclidean distance from vishnupriya.4.5 is 0.7222922
# Euclidean distance from vishnupriya.4.9 is 0.86351436
# Euclidean distance from vishnupriya.4.6 is 0.72586095
# Euclidean distance from vishnupriya.4.1 is 0.7583654
# Euclidean distance from vishnupriya.4.2 is 0.6783441
# Euclidean distance from vishnupriya.4.10 is 0.91174173
# Euclidean distance from vishnupriya.4.7 is 1.0179704
# Euclidean distance from vishnupriya.4.8 is 0.85783887
# Euclidean distance from vishnupriya.4.3 is 0.86418676
# Euclidean distance from vishnupriya.4.4 is 0.8560852
# Euclidean distance from vishnupriya.4.5 is 0.8509691
# Euclidean distance from vishnupriya.4.9 is 1.0321407
# Euclidean distance from vishnupriya.4.6 is 0.94288963
# Euclidean distance from vishnupriya.4.1 is 0.8492166
# Euclidean distance from vishnupriya.4.2 is 0.7982581
# Euclidean distance from vishnupriya.4.10 is 1.084049
# Euclidean distance from vishnupriya.4.7 is 0.88648546
# Euclidean distance from vishnupriya.4.8 is 0.85780734
# Euclidean distance from vishnupriya.4.3 is 0.8251695
# Euclidean distance from vishnupriya.4.4 is 0.8678362
# Euclidean distance from vishnupriya.4.5 is 0.818726
# Euclidean distance from vishnupriya.4.9 is 0.8839441
# Euclidean distance from vishnupriya.4.6 is 0.90294945
# Euclidean distance from vishnupriya.4.1 is 0.8140138
# Euclidean distance from vishnupriya.4.2 is 0.7340544
# Euclidean distance from vishnupriya.4.10 is 0.97835064
# Euclidean distance from vishnupriya.4.7 is 0.9852547
# Euclidean distance from vishnupriya.4.8 is 0.78301686
# Euclidean distance from vishnupriya.4.3 is 0.7974574
# Euclidean distance from vishnupriya.4.4 is 0.7678895
# Euclidean distance from vishnupriya.4.5 is 0.7918948
# Euclidean distance from vishnupriya.4.9 is 0.9940932
# Euclidean distance from vishnupriya.4.6 is 0.917991
# Euclidean distance from vishnupriya.4.1 is 0.7896582
# Euclidean distance from vishnupriya.4.2 is 0.70567137
# Euclidean distance from vishnupriya.4.10 is 1.0540175
# Euclidean distance from vishnupriya.4.7 is 1.1037687
# Euclidean distance from vishnupriya.4.8 is 0.8742838
# Euclidean distance from vishnupriya.4.3 is 0.8751664
# Euclidean distance from vishnupriya.4.4 is 0.8094693
# Euclidean distance from vishnupriya.4.5 is 0.8783039
# Euclidean distance from vishnupriya.4.9 is 1.0672525
# Euclidean distance from vishnupriya.4.6 is 1.0274915
# Euclidean distance from vishnupriya.4.1 is 0.8700236
# Euclidean distance from vishnupriya.4.2 is 0.8512774
# Euclidean distance from vishnupriya.4.10 is 1.1254753
# Euclidean distance from vishnupriya.4.7 is 0.99244165
# Euclidean distance from vishnupriya.4.8 is 0.7057886
# Euclidean distance from vishnupriya.4.3 is 0.7659128
# Euclidean distance from vishnupriya.4.4 is 0.6709725
# Euclidean distance from vishnupriya.4.5 is 0.7427078
# Euclidean distance from vishnupriya.4.9 is 0.9467131
# Euclidean distance from vishnupriya.4.6 is 0.86678916
# Euclidean distance from vishnupriya.4.1 is 0.74914
# Euclidean distance from vishnupriya.4.2 is 0.76570404
# Euclidean distance from vishnupriya.4.10 is 1.00015
# Euclidean distance from vishnupriya.4.7 is 0.81013656
# Euclidean distance from vishnupriya.4.8 is 0.64483887
# Euclidean distance from vishnupriya.4.3 is 0.6607171
# Euclidean distance from vishnupriya.4.4 is 0.6514271
# Euclidean distance from vishnupriya.4.5 is 0.62889934
# Euclidean distance from vishnupriya.4.9 is 0.71646845
# Euclidean distance from vishnupriya.4.6 is 0.75102437
# Euclidean distance from vishnupriya.4.1 is 0.6658144
# Euclidean distance from vishnupriya.4.2 is 0.6462953
# Euclidean distance from vishnupriya.4.10 is 0.81372696
# Euclidean distance from vishnupriya.4.7 is 0.7535532
# Euclidean distance from vishnupriya.4.8 is 0.62013286
# Euclidean distance from vishnupriya.4.3 is 0.64511746
# Euclidean distance from vishnupriya.4.4 is 0.63385963
# Euclidean distance from vishnupriya.4.5 is 0.5820475
# Euclidean distance from vishnupriya.4.9 is 0.6585375
# Euclidean distance from vishnupriya.4.6 is 0.712567
# Euclidean distance from vishnupriya.4.1 is 0.6494909
# Euclidean distance from vishnupriya.4.2 is 0.6105363
# Euclidean distance from vishnupriya.4.10 is 0.7712451
# Euclidean distance from vishnupriya.4.7 is 0.811335
# Euclidean distance from vishnupriya.4.8 is 0.5717136
# Euclidean distance from vishnupriya.4.3 is 0.61803967
# Euclidean distance from vishnupriya.4.4 is 0.5887327
# Euclidean distance from vishnupriya.4.5 is 0.5792199
# Euclidean distance from vishnupriya.4.9 is 0.7027496
# Euclidean distance from vishnupriya.4.6 is 0.73463595
# Euclidean distance from vishnupriya.4.1 is 0.6349994
# Euclidean distance from vishnupriya.4.2 is 0.6277722
# Euclidean distance from vishnupriya.4.10 is 0.77581936
# Euclidean distance from vishnupriya.4.7 is 0.6269582
# Euclidean distance from vishnupriya.4.8 is 0.5052442
# Euclidean distance from vishnupriya.4.3 is 0.71256745
# Euclidean distance from vishnupriya.4.4 is 0.6358851
# Euclidean distance from vishnupriya.4.5 is 0.56649774
# Euclidean distance from vishnupriya.4.9 is 0.51005524
# Euclidean distance from vishnupriya.4.6 is 0.5610134
# Euclidean distance from vishnupriya.4.1 is 0.62079793
# Euclidean distance from vishnupriya.4.2 is 0.71714836
# Euclidean distance from vishnupriya.4.10 is 0.55389005
# Euclidean distance from vishnupriya.4.7 is 0.6138515
# Euclidean distance from vishnupriya.4.8 is 0.6652121
# Euclidean distance from vishnupriya.4.3 is 0.7059128
# Euclidean distance from vishnupriya.4.4 is 0.77610594
# Euclidean distance from vishnupriya.4.5 is 0.63745916
# Euclidean distance from vishnupriya.4.9 is 0.46649718
# Euclidean distance from vishnupriya.4.6 is 0.6833431
# Euclidean distance from vishnupriya.4.1 is 0.71954185
# Euclidean distance from vishnupriya.4.2 is 0.68341386
# Euclidean distance from vishnupriya.4.10 is 0.6150874
# Euclidean distance from vishnupriya.4.7 is 0.6690008
# Euclidean distance from vishnupriya.4.8 is 0.67149395
# Euclidean distance from vishnupriya.4.3 is 0.77369136
# Euclidean distance from vishnupriya.4.4 is 0.7584662
# Euclidean distance from vishnupriya.4.5 is 0.6726821
# Euclidean distance from vishnupriya.4.9 is 0.61346775
# Euclidean distance from vishnupriya.4.6 is 0.67172694
# Euclidean distance from vishnupriya.4.1 is 0.7381263
# Euclidean distance from vishnupriya.4.2 is 0.65899634
# Euclidean distance from vishnupriya.4.10 is 0.7311409
# Euclidean distance from vishnupriya.4.7 is 0.7279031
# Euclidean distance from vishnupriya.4.8 is 0.6617169
# Euclidean distance from vishnupriya.4.3 is 0.79766774
# Euclidean distance from vishnupriya.4.4 is 0.79063207
# Euclidean distance from vishnupriya.4.5 is 0.6779688
# Euclidean distance from vishnupriya.4.9 is 0.7418884
# Euclidean distance from vishnupriya.4.6 is 0.6632272
# Euclidean distance from vishnupriya.4.1 is 0.78057015
# Euclidean distance from vishnupriya.4.2 is 0.63925064
# Euclidean distance from vishnupriya.4.10 is 0.82842916
# Euclidean distance from vishnupriya.4.7 is 0.67445123
# Euclidean distance from vishnupriya.4.8 is 0.6127697
# Euclidean distance from vishnupriya.4.3 is 0.7184
# Euclidean distance from vishnupriya.4.4 is 0.71121866
# Euclidean distance from vishnupriya.4.5 is 0.62636
# Euclidean distance from vishnupriya.4.9 is 0.68130606
# Euclidean distance from vishnupriya.4.6 is 0.60399765
# Euclidean distance from vishnupriya.4.1 is 0.693717
# Euclidean distance from vishnupriya.4.2 is 0.55802983
# Euclidean distance from vishnupriya.4.10 is 0.7559012
# Euclidean distance from vishnupriya.4.7 is 0.8108174
# Euclidean distance from vishnupriya.4.8 is 0.83941597
# Euclidean distance from vishnupriya.4.3 is 0.82325405
# Euclidean distance from vishnupriya.4.4 is 0.9321488
# Euclidean distance from vishnupriya.4.5 is 0.8002843
# Euclidean distance from vishnupriya.4.9 is 0.82856715
# Euclidean distance from vishnupriya.4.6 is 0.78075856
# Euclidean distance from vishnupriya.4.1 is 0.8797004
# Euclidean distance from vishnupriya.4.2 is 0.66505057
# Euclidean distance from vishnupriya.4.10 is 0.88442415
# Euclidean distance from vishnupriya.4.7 is 0.8461573
# Euclidean distance from vishnupriya.4.8 is 0.66881543
# Euclidean distance from vishnupriya.4.3 is 0.8644572
# Euclidean distance from vishnupriya.4.4 is 0.7355068
# Euclidean distance from vishnupriya.4.5 is 0.73636514
# Euclidean distance from vishnupriya.4.9 is 0.83588004
# Euclidean distance from vishnupriya.4.6 is 0.7518125
# Euclidean distance from vishnupriya.4.1 is 0.7650381
# Euclidean distance from vishnupriya.4.2 is 0.7705105
# Euclidean distance from vishnupriya.4.10 is 0.9088146
# Euclidean distance from vishnupriya.4.7 is 0.6053699
# Euclidean distance from vishnupriya.4.8 is 0.67183375
# Euclidean distance from vishnupriya.4.3 is 0.7940653
# Euclidean distance from vishnupriya.4.4 is 0.8060935
# Euclidean distance from vishnupriya.4.5 is 0.6889168
# Euclidean distance from vishnupriya.4.9 is 0.4812786
# Euclidean distance from vishnupriya.4.6 is 0.63390446
# Euclidean distance from vishnupriya.4.1 is 0.75295967
# Euclidean distance from vishnupriya.4.2 is 0.7102599
# Euclidean distance from vishnupriya.4.10 is 0.5926302
# Euclidean distance from vishnupriya.4.7 is 0.58159935
# Euclidean distance from vishnupriya.4.8 is 0.57982004
# Euclidean distance from vishnupriya.4.3 is 0.7464329
# Euclidean distance from vishnupriya.4.4 is 0.73223436
# Euclidean distance from vishnupriya.4.5 is 0.621069
# Euclidean distance from vishnupriya.4.9 is 0.48052567
# Euclidean distance from vishnupriya.4.6 is 0.5684089
# Euclidean distance from vishnupriya.4.1 is 0.7062928
# Euclidean distance from vishnupriya.4.2 is 0.65521026
# Euclidean distance from vishnupriya.4.10 is 0.5642199
# Euclidean distance from vishnupriya.4.7 is 0.685502
# Euclidean distance from vishnupriya.4.8 is 0.5618846
# Euclidean distance from vishnupriya.4.3 is 0.6470862
# Euclidean distance from vishnupriya.4.4 is 0.6854471
# Euclidean distance from vishnupriya.4.5 is 0.6020974
# Euclidean distance from vishnupriya.4.9 is 0.5816337
# Euclidean distance from vishnupriya.4.6 is 0.6652793
# Euclidean distance from vishnupriya.4.1 is 0.67276263
# Euclidean distance from vishnupriya.4.2 is 0.5667821
# Euclidean distance from vishnupriya.4.10 is 0.6817023
# Euclidean distance from vishnupriya.4.7 is 0.6818741
# Euclidean distance from vishnupriya.4.8 is 0.6881303
# Euclidean distance from vishnupriya.4.3 is 0.9840567
# Euclidean distance from vishnupriya.4.4 is 0.90545005
# Euclidean distance from vishnupriya.4.5 is 0.83428913
# Euclidean distance from vishnupriya.4.9 is 0.7478444
# Euclidean distance from vishnupriya.4.6 is 0.5845773
# Euclidean distance from vishnupriya.4.1 is 0.8069414
# Euclidean distance from vishnupriya.4.2 is 0.9362937
# Euclidean distance from vishnupriya.4.10 is 0.6599633
# Euclidean distance from vishnupriya.4.7 is 0.5870712
# Euclidean distance from vishnupriya.4.8 is 0.51221657
# Euclidean distance from vishnupriya.4.3 is 0.72902703
# Euclidean distance from vishnupriya.4.4 is 0.6785326
# Euclidean distance from vishnupriya.4.5 is 0.5719323
# Euclidean distance from vishnupriya.4.9 is 0.56372935
# Euclidean distance from vishnupriya.4.6 is 0.5184212
# Euclidean distance from vishnupriya.4.1 is 0.6506192
# Euclidean distance from vishnupriya.4.2 is 0.65810746
# Euclidean distance from vishnupriya.4.10 is 0.6241549
# Euclidean distance from vishnupriya.4.7 is 0.65011024
# Euclidean distance from vishnupriya.4.8 is 0.57121176
# Euclidean distance from vishnupriya.4.3 is 0.6589947
# Euclidean distance from vishnupriya.4.4 is 0.7074377
# Euclidean distance from vishnupriya.4.5 is 0.5886555
# Euclidean distance from vishnupriya.4.9 is 0.53689796
# Euclidean distance from vishnupriya.4.6 is 0.662944
# Euclidean distance from vishnupriya.4.1 is 0.68084687
# Euclidean distance from vishnupriya.4.2 is 0.62022305
# Euclidean distance from vishnupriya.4.10 is 0.64418215
# Euclidean distance from vishnupriya.4.7 is 0.5929562
# Euclidean distance from vishnupriya.4.8 is 0.57954353
# Euclidean distance from vishnupriya.4.3 is 0.6665533
# Euclidean distance from vishnupriya.4.4 is 0.72184694
# Euclidean distance from vishnupriya.4.5 is 0.58369696
# Euclidean distance from vishnupriya.4.9 is 0.50512505
# Euclidean distance from vishnupriya.4.6 is 0.5806572
# Euclidean distance from vishnupriya.4.1 is 0.6871237
# Euclidean distance from vishnupriya.4.2 is 0.5885151
# Euclidean distance from vishnupriya.4.10 is 0.5801871
# Euclidean distance from vishnupriya.4.7 is 0.5203843
# Euclidean distance from vishnupriya.4.8 is 0.48993975
# Euclidean distance from vishnupriya.4.3 is 0.6054017
# Euclidean distance from vishnupriya.4.4 is 0.6345649
# Euclidean distance from vishnupriya.4.5 is 0.49207723
# Euclidean distance from vishnupriya.4.9 is 0.43269822
# Euclidean distance from vishnupriya.4.6 is 0.4872214
# Euclidean distance from vishnupriya.4.1 is 0.59628105
# Euclidean distance from vishnupriya.4.2 is 0.5407707
# Euclidean distance from vishnupriya.4.10 is 0.50847477
# Euclidean distance from vishnupriya.4.7 is 0.64341515
# Euclidean distance from vishnupriya.4.8 is 0.6526831
# Euclidean distance from vishnupriya.4.3 is 0.81315
# Euclidean distance from vishnupriya.4.4 is 0.8319608
# Euclidean distance from vishnupriya.4.5 is 0.6944822
# Euclidean distance from vishnupriya.4.9 is 0.65119994
# Euclidean distance from vishnupriya.4.6 is 0.6053715
# Euclidean distance from vishnupriya.4.1 is 0.7822099
# Euclidean distance from vishnupriya.4.2 is 0.6724344
# Euclidean distance from vishnupriya.4.10 is 0.695596
# Euclidean distance from vishnupriya.4.7 is 0.62320703
# Euclidean distance from vishnupriya.4.8 is 0.50003135
# Euclidean distance from vishnupriya.4.3 is 0.74719507
# Euclidean distance from vishnupriya.4.4 is 0.647284
# Euclidean distance from vishnupriya.4.5 is 0.58321774
# Euclidean distance from vishnupriya.4.9 is 0.59852797
# Euclidean distance from vishnupriya.4.6 is 0.5035778
# Euclidean distance from vishnupriya.4.1 is 0.65035605
# Euclidean distance from vishnupriya.4.2 is 0.6925679
# Euclidean distance from vishnupriya.4.10 is 0.62750405
# Euclidean distance from vishnupriya.4.7 is 0.6003686
# Euclidean distance from vishnupriya.4.8 is 0.6375284
# Euclidean distance from vishnupriya.4.3 is 0.8839508
# Euclidean distance from vishnupriya.4.4 is 0.8258544
# Euclidean distance from vishnupriya.4.5 is 0.71870786
# Euclidean distance from vishnupriya.4.9 is 0.632287
# Euclidean distance from vishnupriya.4.6 is 0.49499813
# Euclidean distance from vishnupriya.4.1 is 0.7567831
# Euclidean distance from vishnupriya.4.2 is 0.7714297
# Euclidean distance from vishnupriya.4.10 is 0.61856914
# Euclidean distance from vishnupriya.4.7 is 0.6510008
# Euclidean distance from vishnupriya.4.8 is 0.61599296
# Euclidean distance from vishnupriya.4.3 is 0.6967483
# Euclidean distance from vishnupriya.4.4 is 0.72467756
# Euclidean distance from vishnupriya.4.5 is 0.5902005
# Euclidean distance from vishnupriya.4.9 is 0.5806571
# Euclidean distance from vishnupriya.4.6 is 0.6328381
# Euclidean distance from vishnupriya.4.1 is 0.716561
# Euclidean distance from vishnupriya.4.2 is 0.6229618
# Euclidean distance from vishnupriya.4.10 is 0.6870688
# Euclidean distance from vishnupriya.4.7 is 0.64262444
# Euclidean distance from vishnupriya.4.8 is 0.58511585
# Euclidean distance from vishnupriya.4.3 is 0.7896236
# Euclidean distance from vishnupriya.4.4 is 0.7320914
# Euclidean distance from vishnupriya.4.5 is 0.6514547
# Euclidean distance from vishnupriya.4.9 is 0.625624
# Euclidean distance from vishnupriya.4.6 is 0.5487978
# Euclidean distance from vishnupriya.4.1 is 0.71719897
# Euclidean distance from vishnupriya.4.2 is 0.67495817
# Euclidean distance from vishnupriya.4.10 is 0.6696281
# Euclidean distance from vishnupriya.4.7 is 0.5652384
# Euclidean distance from vishnupriya.4.8 is 0.63097125
# Euclidean distance from vishnupriya.4.3 is 0.8650566
# Euclidean distance from vishnupriya.4.4 is 0.81925064
# Euclidean distance from vishnupriya.4.5 is 0.69712687
# Euclidean distance from vishnupriya.4.9 is 0.61670524
# Euclidean distance from vishnupriya.4.6 is 0.46142617
# Euclidean distance from vishnupriya.4.1 is 0.74050266
# Euclidean distance from vishnupriya.4.2 is 0.76923335
# Euclidean distance from vishnupriya.4.10 is 0.5841656
# Euclidean distance from vishnupriya.4.7 is 0.715201
# Euclidean distance from vishnupriya.4.8 is 0.5841239
# Euclidean distance from vishnupriya.4.3 is 0.72680175
# Euclidean distance from vishnupriya.4.4 is 0.6718695
# Euclidean distance from vishnupriya.4.5 is 0.6130001
# Euclidean distance from vishnupriya.4.9 is 0.65535986
# Euclidean distance from vishnupriya.4.6 is 0.62309057
# Euclidean distance from vishnupriya.4.1 is 0.7058913
# Euclidean distance from vishnupriya.4.2 is 0.6608991
# Euclidean distance from vishnupriya.4.10 is 0.7150378
# Euclidean distance from vishnupriya.4.7 is 0.55692405
# Euclidean distance from vishnupriya.4.8 is 0.60136306
# Euclidean distance from vishnupriya.4.3 is 0.6869901
# Euclidean distance from vishnupriya.4.4 is 0.74873745
# Euclidean distance from vishnupriya.4.5 is 0.58352375
# Euclidean distance from vishnupriya.4.9 is 0.47809875
# Euclidean distance from vishnupriya.4.6 is 0.57396233
# Euclidean distance from vishnupriya.4.1 is 0.69024557
# Euclidean distance from vishnupriya.4.2 is 0.610846
# Euclidean distance from vishnupriya.4.10 is 0.5878954
# Euclidean distance from vishnupriya.4.7 is 0.64720625
# Euclidean distance from vishnupriya.4.8 is 0.6464668
# Euclidean distance from vishnupriya.4.3 is 0.79487383
# Euclidean distance from vishnupriya.4.4 is 0.7764667
# Euclidean distance from vishnupriya.4.5 is 0.6580492
# Euclidean distance from vishnupriya.4.9 is 0.6084863
# Euclidean distance from vishnupriya.4.6 is 0.5897166
# Euclidean distance from vishnupriya.4.1 is 0.75926006
# Euclidean distance from vishnupriya.4.2 is 0.7026824
# Euclidean distance from vishnupriya.4.10 is 0.67204344
# Euclidean distance from vishnupriya.4.7 is 0.6385145
# Euclidean distance from vishnupriya.4.8 is 0.55621105
# Euclidean distance from vishnupriya.4.3 is 0.75632423
# Euclidean distance from vishnupriya.4.4 is 0.71896434
# Euclidean distance from vishnupriya.4.5 is 0.6202418
# Euclidean distance from vishnupriya.4.9 is 0.6343421
# Euclidean distance from vishnupriya.4.6 is 0.57022274
# Euclidean distance from vishnupriya.4.1 is 0.70917475
# Euclidean distance from vishnupriya.4.2 is 0.6528595
# Euclidean distance from vishnupriya.4.10 is 0.68776286
# Euclidean distance from vishnupriya.4.7 is 0.63014
# Euclidean distance from vishnupriya.4.8 is 0.58192766
# Euclidean distance from vishnupriya.4.3 is 0.7516183
# Euclidean distance from vishnupriya.4.4 is 0.72452414
# Euclidean distance from vishnupriya.4.5 is 0.6177978
# Euclidean distance from vishnupriya.4.9 is 0.6207171
# Euclidean distance from vishnupriya.4.6 is 0.53539395
# Euclidean distance from vishnupriya.4.1 is 0.6982531
# Euclidean distance from vishnupriya.4.2 is 0.63619626
# Euclidean distance from vishnupriya.4.10 is 0.6678772
# Euclidean distance from vishnupriya.4.7 is 0.65616786
# Euclidean distance from vishnupriya.4.8 is 0.6498604
# Euclidean distance from vishnupriya.4.3 is 0.73466253
# Euclidean distance from vishnupriya.4.4 is 0.7458535
# Euclidean distance from vishnupriya.4.5 is 0.6132942
# Euclidean distance from vishnupriya.4.9 is 0.58469653
# Euclidean distance from vishnupriya.4.6 is 0.6193587
# Euclidean distance from vishnupriya.4.1 is 0.7284523
# Euclidean distance from vishnupriya.4.2 is 0.64834636
# Euclidean distance from vishnupriya.4.10 is 0.69025505
# Euclidean distance from vishnupriya.4.7 is 0.5282186
# Euclidean distance from vishnupriya.4.8 is 0.64479816
# Euclidean distance from vishnupriya.4.3 is 0.69774646
# Euclidean distance from vishnupriya.4.4 is 0.76417005
# Euclidean distance from vishnupriya.4.5 is 0.58320725
# Euclidean distance from vishnupriya.4.9 is 0.43126044
# Euclidean distance from vishnupriya.4.6 is 0.56257457
# Euclidean distance from vishnupriya.4.1 is 0.67276907
# Euclidean distance from vishnupriya.4.2 is 0.6326108
# Euclidean distance from vishnupriya.4.10 is 0.53914434
# Euclidean distance from vishnupriya.4.7 is 0.6689062
# Euclidean distance from vishnupriya.4.8 is 0.668262
# Euclidean distance from vishnupriya.4.3 is 0.84285676
# Euclidean distance from vishnupriya.4.4 is 0.8020644
# Euclidean distance from vishnupriya.4.5 is 0.69210094
# Euclidean distance from vishnupriya.4.9 is 0.6178536
# Euclidean distance from vishnupriya.4.6 is 0.5981565
# Euclidean distance from vishnupriya.4.1 is 0.7528013
# Euclidean distance from vishnupriya.4.2 is 0.7646457
# Euclidean distance from vishnupriya.4.10 is 0.6717641
# Euclidean distance from vishnupriya.4.7 is 0.6343
# Euclidean distance from vishnupriya.4.8 is 0.5570528
# Euclidean distance from vishnupriya.4.3 is 0.60663205
# Euclidean distance from vishnupriya.4.4 is 0.618604
# Euclidean distance from vishnupriya.4.5 is 0.5031031
# Euclidean distance from vishnupriya.4.9 is 0.5392604
# Euclidean distance from vishnupriya.4.6 is 0.59976774
# Euclidean distance from vishnupriya.4.1 is 0.60018915
# Euclidean distance from vishnupriya.4.2 is 0.55602014
# Euclidean distance from vishnupriya.4.10 is 0.6585357
# Euclidean distance from vishnupriya.4.7 is 0.58848786
# Euclidean distance from vishnupriya.4.8 is 0.45138443
# Euclidean distance from vishnupriya.4.3 is 0.6913398
# Euclidean distance from vishnupriya.4.4 is 0.65182006
# Euclidean distance from vishnupriya.4.5 is 0.53446585
# Euclidean distance from vishnupriya.4.9 is 0.6313587
# Euclidean distance from vishnupriya.4.6 is 0.45561296
# Euclidean distance from vishnupriya.4.1 is 0.61405694
# Euclidean distance from vishnupriya.4.2 is 0.5720777
# Euclidean distance from vishnupriya.4.10 is 0.6565965
# Euclidean distance from vishnupriya.4.7 is 0.60461944
# Euclidean distance from vishnupriya.4.8 is 0.65245277
# Euclidean distance from vishnupriya.4.3 is 0.8208342
# Euclidean distance from vishnupriya.4.4 is 0.80089855
# Euclidean distance from vishnupriya.4.5 is 0.6795594
# Euclidean distance from vishnupriya.4.9 is 0.5741936
# Euclidean distance from vishnupriya.4.6 is 0.54866576
# Euclidean distance from vishnupriya.4.1 is 0.7558144
# Euclidean distance from vishnupriya.4.2 is 0.72170645
# Euclidean distance from vishnupriya.4.10 is 0.6244757
# Euclidean distance from vishnupriya.4.7 is 0.5482386
# Euclidean distance from vishnupriya.4.8 is 0.5649038
# Euclidean distance from vishnupriya.4.3 is 0.85064965
# Euclidean distance from vishnupriya.4.4 is 0.7973571
# Euclidean distance from vishnupriya.4.5 is 0.6863836
# Euclidean distance from vishnupriya.4.9 is 0.54088044
# Euclidean distance from vishnupriya.4.6 is 0.5430151
# Euclidean distance from vishnupriya.4.1 is 0.71899706
# Euclidean distance from vishnupriya.4.2 is 0.76488733
# Euclidean distance from vishnupriya.4.10 is 0.5524522
# Euclidean distance from vishnupriya.4.7 is 0.585683
# Euclidean distance from vishnupriya.4.8 is 0.66086024
# Euclidean distance from vishnupriya.4.3 is 0.8057478
# Euclidean distance from vishnupriya.4.4 is 0.81331354
# Euclidean distance from vishnupriya.4.5 is 0.68361086
# Euclidean distance from vishnupriya.4.9 is 0.53233767
# Euclidean distance from vishnupriya.4.6 is 0.5815559
# Euclidean distance from vishnupriya.4.1 is 0.7606677
# Euclidean distance from vishnupriya.4.2 is 0.6983394
# Euclidean distance from vishnupriya.4.10 is 0.6018752
# Euclidean distance from vishnupriya.4.7 is 0.59633166
# Euclidean distance from vishnupriya.4.8 is 0.5542523
# Euclidean distance from vishnupriya.4.3 is 0.72521037
# Euclidean distance from vishnupriya.4.4 is 0.7003361
# Euclidean distance from vishnupriya.4.5 is 0.5870932
# Euclidean distance from vishnupriya.4.9 is 0.5791225
# Euclidean distance from vishnupriya.4.6 is 0.52312833
# Euclidean distance from vishnupriya.4.1 is 0.67500585
# Euclidean distance from vishnupriya.4.2 is 0.58914465
# Euclidean distance from vishnupriya.4.10 is 0.6255819
# Euclidean distance from vishnupriya.4.7 is 0.62673414
# Euclidean distance from vishnupriya.4.8 is 0.6559316
# Euclidean distance from vishnupriya.4.3 is 0.64962006
# Euclidean distance from vishnupriya.4.4 is 0.7045953
# Euclidean distance from vishnupriya.4.5 is 0.5786586
# Euclidean distance from vishnupriya.4.9 is 0.5737117
# Euclidean distance from vishnupriya.4.6 is 0.6479938
# Euclidean distance from vishnupriya.4.1 is 0.6965927
# Euclidean distance from vishnupriya.4.2 is 0.5482286
# Euclidean distance from vishnupriya.4.10 is 0.6983119
# Euclidean distance from vishnupriya.4.7 is 0.6208787
# Euclidean distance from vishnupriya.4.8 is 0.66117185
# Euclidean distance from vishnupriya.4.3 is 0.73733
# Euclidean distance from vishnupriya.4.4 is 0.7279636
# Euclidean distance from vishnupriya.4.5 is 0.6071617
# Euclidean distance from vishnupriya.4.9 is 0.53609526
# Euclidean distance from vishnupriya.4.6 is 0.6011089
# Euclidean distance from vishnupriya.4.1 is 0.7185981
# Euclidean distance from vishnupriya.4.2 is 0.6853921
# Euclidean distance from vishnupriya.4.10 is 0.63339204
# Euclidean distance from vishnupriya.4.7 is 0.7248606
# Euclidean distance from vishnupriya.4.8 is 0.7945677
# Euclidean distance from vishnupriya.4.3 is 0.78927344
# Euclidean distance from vishnupriya.4.4 is 0.8632479
# Euclidean distance from vishnupriya.4.5 is 0.7596578
# Euclidean distance from vishnupriya.4.9 is 0.63857394
# Euclidean distance from vishnupriya.4.6 is 0.7402993
# Euclidean distance from vishnupriya.4.1 is 0.8097275
# Euclidean distance from vishnupriya.4.2 is 0.7126026
# Euclidean distance from vishnupriya.4.10 is 0.73386896
# Euclidean distance from vishnupriya.4.7 is 0.6982379
# Euclidean distance from vishnupriya.4.8 is 0.7560293
# Euclidean distance from vishnupriya.4.3 is 0.7624744
# Euclidean distance from vishnupriya.4.4 is 0.83846545
# Euclidean distance from vishnupriya.4.5 is 0.7310455
# Euclidean distance from vishnupriya.4.9 is 0.616883
# Euclidean distance from vishnupriya.4.6 is 0.72674984
# Euclidean distance from vishnupriya.4.1 is 0.7863822
# Euclidean distance from vishnupriya.4.2 is 0.64740837
# Euclidean distance from vishnupriya.4.10 is 0.7342566
# Euclidean distance from vishnupriya.4.7 is 0.59283733
# Euclidean distance from vishnupriya.4.8 is 0.6720809
# Euclidean distance from vishnupriya.4.3 is 0.69492996
# Euclidean distance from vishnupriya.4.4 is 0.73022944
# Euclidean distance from vishnupriya.4.5 is 0.62780315
# Euclidean distance from vishnupriya.4.9 is 0.48986325
# Euclidean distance from vishnupriya.4.6 is 0.6484447
# Euclidean distance from vishnupriya.4.1 is 0.6640696
# Euclidean distance from vishnupriya.4.2 is 0.6208058
# Euclidean distance from vishnupriya.4.10 is 0.63787967
# Euclidean distance from vishnupriya.4.7 is 0.50629234
# Euclidean distance from vishnupriya.4.8 is 0.6222474
# Euclidean distance from vishnupriya.4.3 is 0.750266
# Euclidean distance from vishnupriya.4.4 is 0.770311
# Euclidean distance from vishnupriya.4.5 is 0.640989
# Euclidean distance from vishnupriya.4.9 is 0.37741336
# Euclidean distance from vishnupriya.4.6 is 0.55702543
# Euclidean distance from vishnupriya.4.1 is 0.6794083
# Euclidean distance from vishnupriya.4.2 is 0.67177224
# Euclidean distance from vishnupriya.4.10 is 0.4645936
# Euclidean distance from vishnupriya.4.7 is 0.60535836
# Euclidean distance from vishnupriya.4.8 is 0.6510554
# Euclidean distance from vishnupriya.4.3 is 0.64846736
# Euclidean distance from vishnupriya.4.4 is 0.7191458
# Euclidean distance from vishnupriya.4.5 is 0.5887358
# Euclidean distance from vishnupriya.4.9 is 0.50373924
# Euclidean distance from vishnupriya.4.6 is 0.64607733
# Euclidean distance from vishnupriya.4.1 is 0.67766786
# Euclidean distance from vishnupriya.4.2 is 0.560394
# Euclidean distance from vishnupriya.4.10 is 0.6485101
# Euclidean distance from vishnupriya.4.7 is 0.60028327
# Euclidean distance from vishnupriya.4.8 is 0.7686753
# Euclidean distance from vishnupriya.4.3 is 0.8592867
# Euclidean distance from vishnupriya.4.4 is 0.9014656
# Euclidean distance from vishnupriya.4.5 is 0.7563395
# Euclidean distance from vishnupriya.4.9 is 0.55601037
# Euclidean distance from vishnupriya.4.6 is 0.63398314
# Euclidean distance from vishnupriya.4.1 is 0.81315255
# Euclidean distance from vishnupriya.4.2 is 0.73397166
# Euclidean distance from vishnupriya.4.10 is 0.6258441
# Euclidean distance from vishnupriya.4.7 is 0.6998852
# Euclidean distance from vishnupriya.4.8 is 0.69863975
# Euclidean distance from vishnupriya.4.3 is 0.70814794
# Euclidean distance from vishnupriya.4.4 is 0.7978406
# Euclidean distance from vishnupriya.4.5 is 0.66724706
# Euclidean distance from vishnupriya.4.9 is 0.60349315
# Euclidean distance from vishnupriya.4.6 is 0.7343077
# Euclidean distance from vishnupriya.4.1 is 0.7674811
# Euclidean distance from vishnupriya.4.2 is 0.5930208
# Euclidean distance from vishnupriya.4.10 is 0.74227166
# Euclidean distance from vishnupriya.4.7 is 0.73799855
# Euclidean distance from vishnupriya.4.8 is 0.673025
# Euclidean distance from vishnupriya.4.3 is 0.6801851
# Euclidean distance from vishnupriya.4.4 is 0.6981955
# Euclidean distance from vishnupriya.4.5 is 0.6146457
# Euclidean distance from vishnupriya.4.9 is 0.657159
# Euclidean distance from vishnupriya.4.6 is 0.72666144
# Euclidean distance from vishnupriya.4.1 is 0.705396
# Euclidean distance from vishnupriya.4.2 is 0.59872675
# Euclidean distance from vishnupriya.4.10 is 0.7873373
# Euclidean distance from vishnupriya.4.7 is 0.60503876
# Euclidean distance from vishnupriya.4.8 is 0.7591103
# Euclidean distance from vishnupriya.4.3 is 0.84083915
# Euclidean distance from vishnupriya.4.4 is 0.8383841
# Euclidean distance from vishnupriya.4.5 is 0.7322556
# Euclidean distance from vishnupriya.4.9 is 0.46243656
# Euclidean distance from vishnupriya.4.6 is 0.6747594
# Euclidean distance from vishnupriya.4.1 is 0.75836396
# Euclidean distance from vishnupriya.4.2 is 0.8167053
# Euclidean distance from vishnupriya.4.10 is 0.5384964
# Euclidean distance from vishnupriya.4.7 is 0.5812535
# Euclidean distance from vishnupriya.4.8 is 0.72548515
# Euclidean distance from vishnupriya.4.3 is 0.84517443
# Euclidean distance from vishnupriya.4.4 is 0.8591037
# Euclidean distance from vishnupriya.4.5 is 0.75067943
# Euclidean distance from vishnupriya.4.9 is 0.40924224
# Euclidean distance from vishnupriya.4.6 is 0.70105606
# Euclidean distance from vishnupriya.4.1 is 0.73005104
# Euclidean distance from vishnupriya.4.2 is 0.8455517
# Euclidean distance from vishnupriya.4.10 is 0.44786778
# Euclidean distance from vishnupriya.4.7 is 0.69342667
# Euclidean distance from vishnupriya.4.8 is 0.71565264
# Euclidean distance from vishnupriya.4.3 is 0.7659651
# Euclidean distance from vishnupriya.4.4 is 0.8631384
# Euclidean distance from vishnupriya.4.5 is 0.7223891
# Euclidean distance from vishnupriya.4.9 is 0.61973804
# Euclidean distance from vishnupriya.4.6 is 0.6860879
# Euclidean distance from vishnupriya.4.1 is 0.770423
# Euclidean distance from vishnupriya.4.2 is 0.68282294
# Euclidean distance from vishnupriya.4.10 is 0.6799168
# Euclidean distance from vishnupriya.4.7 is 1.0017394
# Euclidean distance from vishnupriya.4.8 is 0.8868559
# Euclidean distance from vishnupriya.4.3 is 0.89692944
# Euclidean distance from vishnupriya.4.4 is 0.91204584
# Euclidean distance from vishnupriya.4.5 is 0.88621384
# Euclidean distance from vishnupriya.4.9 is 1.0008662
# Euclidean distance from vishnupriya.4.6 is 0.9071466
# Euclidean distance from vishnupriya.4.1 is 0.9442882
# Euclidean distance from vishnupriya.4.2 is 0.78857315
# Euclidean distance from vishnupriya.4.10 is 1.0555571
# Euclidean distance from vishnupriya.4.7 is 0.75610495
# Euclidean distance from vishnupriya.4.8 is 0.748247
# Euclidean distance from vishnupriya.4.3 is 0.73273486
# Euclidean distance from vishnupriya.4.4 is 0.8056307
# Euclidean distance from vishnupriya.4.5 is 0.71081793
# Euclidean distance from vishnupriya.4.9 is 0.69493365
# Euclidean distance from vishnupriya.4.6 is 0.7368848
# Euclidean distance from vishnupriya.4.1 is 0.7623721
# Euclidean distance from vishnupriya.4.2 is 0.6675061
# Euclidean distance from vishnupriya.4.10 is 0.7855189
# Euclidean distance from vishnupriya.4.7 is 0.8751068
# Euclidean distance from vishnupriya.4.8 is 0.73493886
# Euclidean distance from vishnupriya.4.3 is 0.7983617
# Euclidean distance from vishnupriya.4.4 is 0.79737496
# Euclidean distance from vishnupriya.4.5 is 0.7390818
# Euclidean distance from vishnupriya.4.9 is 0.86174864
# Euclidean distance from vishnupriya.4.6 is 0.79260194
# Euclidean distance from vishnupriya.4.1 is 0.7975719
# Euclidean distance from vishnupriya.4.2 is 0.6851723
# Euclidean distance from vishnupriya.4.10 is 0.9489465
# Euclidean distance from vishnupriya.4.7 is 0.8581275
# Euclidean distance from vishnupriya.4.8 is 0.8290675
# Euclidean distance from vishnupriya.4.3 is 0.823241
# Euclidean distance from vishnupriya.4.4 is 0.8547002
# Euclidean distance from vishnupriya.4.5 is 0.78372234
# Euclidean distance from vishnupriya.4.9 is 0.80938447
# Euclidean distance from vishnupriya.4.6 is 0.8561288
# Euclidean distance from vishnupriya.4.1 is 0.85239476
# Euclidean distance from vishnupriya.4.2 is 0.7449017
# Euclidean distance from vishnupriya.4.10 is 0.9213567
# Euclidean distance from vishnupriya.4.7 is 0.5866105
# Euclidean distance from vishnupriya.4.8 is 0.64616925
# Euclidean distance from vishnupriya.4.3 is 0.6713262
# Euclidean distance from vishnupriya.4.4 is 0.7855629
# Euclidean distance from vishnupriya.4.5 is 0.63830423
# Euclidean distance from vishnupriya.4.9 is 0.5366869
# Euclidean distance from vishnupriya.4.6 is 0.6027391
# Euclidean distance from vishnupriya.4.1 is 0.6814791
# Euclidean distance from vishnupriya.4.2 is 0.56158364
# Euclidean distance from vishnupriya.4.10 is 0.5942328
# Euclidean distance from vishnupriya.4.7 is 0.6025888
# Euclidean distance from vishnupriya.4.8 is 0.59374315
# Euclidean distance from vishnupriya.4.3 is 0.5698677
# Euclidean distance from vishnupriya.4.4 is 0.6501389
# Euclidean distance from vishnupriya.4.5 is 0.5340535
# Euclidean distance from vishnupriya.4.9 is 0.47791946
# Euclidean distance from vishnupriya.4.6 is 0.6833655
# Euclidean distance from vishnupriya.4.1 is 0.5966853
# Euclidean distance from vishnupriya.4.2 is 0.53553337
# Euclidean distance from vishnupriya.4.10 is 0.64139014
# Euclidean distance from vishnupriya.4.7 is 0.7198838
# Euclidean distance from vishnupriya.4.8 is 0.6369713
# Euclidean distance from vishnupriya.4.3 is 0.6577131
# Euclidean distance from vishnupriya.4.4 is 0.69345176
# Euclidean distance from vishnupriya.4.5 is 0.6102492
# Euclidean distance from vishnupriya.4.9 is 0.6082825
# Euclidean distance from vishnupriya.4.6 is 0.6915807
# Euclidean distance from vishnupriya.4.1 is 0.68165576
# Euclidean distance from vishnupriya.4.2 is 0.60502416
# Euclidean distance from vishnupriya.4.10 is 0.7207373
# Euclidean distance from vishnupriya.4.7 is 0.64100933
# Euclidean distance from vishnupriya.4.8 is 0.6842736
# Euclidean distance from vishnupriya.4.3 is 0.68030316
# Euclidean distance from vishnupriya.4.4 is 0.771771
# Euclidean distance from vishnupriya.4.5 is 0.6190419
# Euclidean distance from vishnupriya.4.9 is 0.542098
# Euclidean distance from vishnupriya.4.6 is 0.67833465
# Euclidean distance from vishnupriya.4.1 is 0.73288035
# Euclidean distance from vishnupriya.4.2 is 0.6175312
# Euclidean distance from vishnupriya.4.10 is 0.6682134
# Euclidean distance from vishnupriya.4.7 is 0.6447938
# Euclidean distance from vishnupriya.4.8 is 0.7698354
# Euclidean distance from vishnupriya.4.3 is 0.8834982
# Euclidean distance from vishnupriya.4.4 is 0.87295973
# Euclidean distance from vishnupriya.4.5 is 0.745897
# Euclidean distance from vishnupriya.4.9 is 0.5795766
# Euclidean distance from vishnupriya.4.6 is 0.630262
# Euclidean distance from vishnupriya.4.1 is 0.8049119
# Euclidean distance from vishnupriya.4.2 is 0.82852
# Euclidean distance from vishnupriya.4.10 is 0.6210919
# Euclidean distance from vishnupriya.4.7 is 0.6881929
# Euclidean distance from vishnupriya.4.8 is 0.66509247
# Euclidean distance from vishnupriya.4.3 is 0.7056449
# Euclidean distance from vishnupriya.4.4 is 0.73925203
# Euclidean distance from vishnupriya.4.5 is 0.63961065
# Euclidean distance from vishnupriya.4.9 is 0.60602355
# Euclidean distance from vishnupriya.4.6 is 0.6843448
# Euclidean distance from vishnupriya.4.1 is 0.7166917
# Euclidean distance from vishnupriya.4.2 is 0.6109996
# Euclidean distance from vishnupriya.4.10 is 0.7165324
# Euclidean distance from vishnupriya.4.7 is 0.58130056
# Euclidean distance from vishnupriya.4.8 is 0.602707
# Euclidean distance from vishnupriya.4.3 is 0.69085246
# Euclidean distance from vishnupriya.4.4 is 0.70879585
# Euclidean distance from vishnupriya.4.5 is 0.5720672
# Euclidean distance from vishnupriya.4.9 is 0.47383904
# Euclidean distance from vishnupriya.4.6 is 0.572508
# Euclidean distance from vishnupriya.4.1 is 0.65715516
# Euclidean distance from vishnupriya.4.2 is 0.64146274
# Euclidean distance from vishnupriya.4.10 is 0.55461526
# Euclidean distance from vishnupriya.4.7 is 0.5825894
# Euclidean distance from vishnupriya.4.8 is 0.6116995
# Euclidean distance from vishnupriya.4.3 is 0.76511985
# Euclidean distance from vishnupriya.4.4 is 0.7544662
# Euclidean distance from vishnupriya.4.5 is 0.6356843
# Euclidean distance from vishnupriya.4.9 is 0.4557132
# Euclidean distance from vishnupriya.4.6 is 0.5997532
# Euclidean distance from vishnupriya.4.1 is 0.6763088
# Euclidean distance from vishnupriya.4.2 is 0.6955441
# Euclidean distance from vishnupriya.4.10 is 0.540233
# Euclidean distance from vishnupriya.4.7 is 0.6538308
# Euclidean distance from vishnupriya.4.8 is 0.7312144
# Euclidean distance from vishnupriya.4.3 is 0.86088395
# Euclidean distance from vishnupriya.4.4 is 0.8631986
# Euclidean distance from vishnupriya.4.5 is 0.7398704
# Euclidean distance from vishnupriya.4.9 is 0.68602484
# Euclidean distance from vishnupriya.4.6 is 0.6371988
# Euclidean distance from vishnupriya.4.1 is 0.83465534
# Euclidean distance from vishnupriya.4.2 is 0.7024894
# Euclidean distance from vishnupriya.4.10 is 0.73993146
# Euclidean distance from vishnupriya.4.7 is 0.83793676
# Euclidean distance from vishnupriya.4.8 is 0.57708794
# Euclidean distance from vishnupriya.4.3 is 0.7284598
# Euclidean distance from vishnupriya.4.4 is 0.57347316
# Euclidean distance from vishnupriya.4.5 is 0.6069122
# Euclidean distance from vishnupriya.4.9 is 0.8007377
# Euclidean distance from vishnupriya.4.6 is 0.78703797
# Euclidean distance from vishnupriya.4.1 is 0.672561
# Euclidean distance from vishnupriya.4.2 is 0.69456667
# Euclidean distance from vishnupriya.4.10 is 0.8954581
# Euclidean distance from vishnupriya.4.7 is 0.7391863
# Euclidean distance from vishnupriya.4.8 is 0.6509224
# Euclidean distance from vishnupriya.4.3 is 0.75993407
# Euclidean distance from vishnupriya.4.4 is 0.6873289
# Euclidean distance from vishnupriya.4.5 is 0.6427714
# Euclidean distance from vishnupriya.4.9 is 0.80500597
# Euclidean distance from vishnupriya.4.6 is 0.68836623
# Euclidean distance from vishnupriya.4.1 is 0.6993033
# Euclidean distance from vishnupriya.4.2 is 0.6590481
# Euclidean distance from vishnupriya.4.10 is 0.8444322
# Euclidean distance from vishnupriya.4.7 is 0.5812835
# Euclidean distance from vishnupriya.4.8 is 0.63405913
# Euclidean distance from vishnupriya.4.3 is 0.84984016
# Euclidean distance from vishnupriya.4.4 is 0.8026087
# Euclidean distance from vishnupriya.4.5 is 0.6929984
# Euclidean distance from vishnupriya.4.9 is 0.6237699
# Euclidean distance from vishnupriya.4.6 is 0.56482464
# Euclidean distance from vishnupriya.4.1 is 0.68443274
# Euclidean distance from vishnupriya.4.2 is 0.7888506
# Euclidean distance from vishnupriya.4.10 is 0.6096144
# Euclidean distance from vishnupriya.4.7 is 0.81539595
# Euclidean distance from vishnupriya.4.8 is 0.54583836
# Euclidean distance from vishnupriya.4.3 is 0.7312811
# Euclidean distance from vishnupriya.4.4 is 0.557446
# Euclidean distance from vishnupriya.4.5 is 0.6038971
# Euclidean distance from vishnupriya.4.9 is 0.83171076
# Euclidean distance from vishnupriya.4.6 is 0.71252906
# Euclidean distance from vishnupriya.4.1 is 0.67654747
# ...
# Euclidean distance from vishnupriya.4.8 is 0.6681968
# Euclidean distance from vishnupriya.4.3 is 0.80451703
# Euclidean distance from vishnupriya.4.4 is 0.7620874
# Euclidean distance from vishnupriya.4.5 is 0.68280685
# Euclidean distance from vishnupriya.4.9 is 0.67937016
# Euclidean distance from vishnupriya.4.6 is 0.6410954
# Euclidean distance from vishnupriya.4.1 is 0.76103896
# Euclidean distance from vishnupriya.4.2 is 0.6704147
# Euclidean distance from vishnupriya.4.10 is 0.7684865
# Euclidean distance from vishnupriya.4.7 is 0.66820633
# Euclidean distance from vishnupriya.4.8 is 0.6273037
# Euclidean distance from vishnupriya.4.3 is 0.7185047
# Euclidean distance from vishnupriya.4.4 is 0.70874286
# Euclidean distance from vishnupriya.4.5 is 0.62728125
# Euclidean distance from vishnupriya.4.9 is 0.65648407
# Euclidean distance from vishnupriya.4.6 is 0.64604515
# Euclidean distance from vishnupriya.4.1 is 0.725805
# Euclidean distance from vishnupriya.4.2 is 0.59012806
# Euclidean distance from vishnupriya.4.10 is 0.7618404
# Euclidean distance from vishnupriya.4.7 is 0.72059363
# Euclidean distance from vishnupriya.4.8 is 0.79504794
# Euclidean distance from vishnupriya.4.3 is 0.8544583
# Euclidean distance from vishnupriya.4.4 is 0.89686173
# Euclidean distance from vishnupriya.4.5 is 0.7659395
# Euclidean distance from vishnupriya.4.9 is 0.69369924
# Euclidean distance from vishnupriya.4.6 is 0.7587525
# Euclidean distance from vishnupriya.4.1 is 0.87845707
# Euclidean distance from vishnupriya.4.2 is 0.70714444
# Euclidean distance from vishnupriya.4.10 is 0.81029403
# Euclidean distance from vishnupriya.4.7 is 0.84687173
# Euclidean distance from vishnupriya.4.8 is 0.72673863
# Euclidean distance from vishnupriya.4.3 is 0.7425451
# Euclidean distance from vishnupriya.4.4 is 0.6992156
# Euclidean distance from vishnupriya.4.5 is 0.67828804
# Euclidean distance from vishnupriya.4.9 is 0.8079919
# Euclidean distance from vishnupriya.4.6 is 0.8080792
# Euclidean distance from vishnupriya.4.1 is 0.7849883
# Euclidean distance from vishnupriya.4.2 is 0.66604763
# Euclidean distance from vishnupriya.4.10 is 0.92433053
# Euclidean distance from vishnupriya.4.7 is 0.72147197
# Euclidean distance from vishnupriya.4.8 is 0.7058107
# Euclidean distance from vishnupriya.4.3 is 0.7154717
# Euclidean distance from vishnupriya.4.4 is 0.75604737
# Euclidean distance from vishnupriya.4.5 is 0.64616203
# Euclidean distance from vishnupriya.4.9 is 0.70186645
# Euclidean distance from vishnupriya.4.6 is 0.7227396
# Euclidean distance from vishnupriya.4.1 is 0.7750384
# Euclidean distance from vishnupriya.4.2 is 0.61150277
# Euclidean distance from vishnupriya.4.10 is 0.82131875
# Euclidean distance from vishnupriya.4.7 is 0.70296794
# Euclidean distance from vishnupriya.4.8 is 0.6621051
# Euclidean distance from vishnupriya.4.3 is 0.6892697
# Euclidean distance from vishnupriya.4.4 is 0.72048146
# Euclidean distance from vishnupriya.4.5 is 0.60636467
# Euclidean distance from vishnupriya.4.9 is 0.70790875
# Euclidean distance from vishnupriya.4.6 is 0.6971602
# Euclidean distance from vishnupriya.4.1 is 0.7379291
# Euclidean distance from vishnupriya.4.2 is 0.5867732
# Euclidean distance from vishnupriya.4.10 is 0.8069291
# Euclidean distance from vishnupriya.4.7 is 0.7593616
# Euclidean distance from vishnupriya.4.8 is 0.6965201
# Euclidean distance from vishnupriya.4.3 is 0.72094357
# Euclidean distance from vishnupriya.4.4 is 0.7041671
# Euclidean distance from vishnupriya.4.5 is 0.62495255
# Euclidean distance from vishnupriya.4.9 is 0.7449316
# Euclidean distance from vishnupriya.4.6 is 0.7346272
# Euclidean distance from vishnupriya.4.1 is 0.76501644
# Euclidean distance from vishnupriya.4.2 is 0.6318633
# Euclidean distance from vishnupriya.4.10 is 0.87045306
# Euclidean distance from vishnupriya.4.7 is 0.72421813
# Euclidean distance from vishnupriya.4.8 is 0.6293958
# Euclidean distance from vishnupriya.4.3 is 0.6975612
# Euclidean distance from vishnupriya.4.4 is 0.6472699
# Euclidean distance from vishnupriya.4.5 is 0.5881892
# Euclidean distance from vishnupriya.4.9 is 0.71254665
# Euclidean distance from vishnupriya.4.6 is 0.65028155
# Euclidean distance from vishnupriya.4.1 is 0.72162503
# Euclidean distance from vishnupriya.4.2 is 0.6021567
# Euclidean distance from vishnupriya.4.10 is 0.8068043
# Euclidean distance from vishnupriya.4.7 is 0.9214656
# Euclidean distance from vishnupriya.4.8 is 0.65032417
# Euclidean distance from vishnupriya.4.3 is 0.78811795
# Euclidean distance from vishnupriya.4.4 is 0.6213589
# Euclidean distance from vishnupriya.4.5 is 0.6888673
# Euclidean distance from vishnupriya.4.9 is 0.9009745
# Euclidean distance from vishnupriya.4.6 is 0.81514096
# Euclidean distance from vishnupriya.4.1 is 0.7442744
# Euclidean distance from vishnupriya.4.2 is 0.75152224
# Euclidean distance from vishnupriya.4.10 is 0.9768192
# Euclidean distance from vishnupriya.4.7 is 0.7879626
# Euclidean distance from vishnupriya.4.8 is 0.67574424
# Euclidean distance from vishnupriya.4.3 is 0.73559093
# Euclidean distance from vishnupriya.4.4 is 0.71405965
# Euclidean distance from vishnupriya.4.5 is 0.6498313
# Euclidean distance from vishnupriya.4.9 is 0.7905086
# Euclidean distance from vishnupriya.4.6 is 0.73417866
# Euclidean distance from vishnupriya.4.1 is 0.77689135
# Euclidean distance from vishnupriya.4.2 is 0.63446254
# Euclidean distance from vishnupriya.4.10 is 0.8863592
# Euclidean distance from vishnupriya.4.7 is 0.78514236
# Euclidean distance from vishnupriya.4.8 is 0.7135655
# Euclidean distance from vishnupriya.4.3 is 0.73716503
# Euclidean distance from vishnupriya.4.4 is 0.7366307
# Euclidean distance from vishnupriya.4.5 is 0.67464304
# Euclidean distance from vishnupriya.4.9 is 0.75456667
# Euclidean distance from vishnupriya.4.6 is 0.75940686
# Euclidean distance from vishnupriya.4.1 is 0.78913206
# Euclidean distance from vishnupriya.4.2 is 0.64956766
# Euclidean distance from vishnupriya.4.10 is 0.8661155
# Euclidean distance from vishnupriya.4.7 is 0.73965824
# Euclidean distance from vishnupriya.4.8 is 0.68668634
# Euclidean distance from vishnupriya.4.3 is 0.7215453
# Euclidean distance from vishnupriya.4.4 is 0.7445465
# Euclidean distance from vishnupriya.4.5 is 0.6665627
# Euclidean distance from vishnupriya.4.9 is 0.6701443
# Euclidean distance from vishnupriya.4.6 is 0.7293025
# Euclidean distance from vishnupriya.4.1 is 0.78423154
# Euclidean distance from vishnupriya.4.2 is 0.6320539
# Euclidean distance from vishnupriya.4.10 is 0.7915008
# Euclidean distance from vishnupriya.4.7 is 0.6943858
# Euclidean distance from vishnupriya.4.8 is 0.51797706
# Euclidean distance from vishnupriya.4.3 is 0.6610467
# Euclidean distance from vishnupriya.4.4 is 0.5797562
# Euclidean distance from vishnupriya.4.5 is 0.54497117
# Euclidean distance from vishnupriya.4.9 is 0.6724498
# Euclidean distance from vishnupriya.4.6 is 0.6241105
# Euclidean distance from vishnupriya.4.1 is 0.6420137
# Euclidean distance from vishnupriya.4.2 is 0.5710811
# Euclidean distance from vishnupriya.4.10 is 0.7629277
# Euclidean distance from vishnupriya.4.7 is 0.7933698
# Euclidean distance from vishnupriya.4.8 is 0.54885405
# Euclidean distance from vishnupriya.4.3 is 0.70558286
# Euclidean distance from vishnupriya.4.4 is 0.5354913
# Euclidean distance from vishnupriya.4.5 is 0.5844877
# Euclidean distance from vishnupriya.4.9 is 0.7859823
# Euclidean distance from vishnupriya.4.6 is 0.71765363
# Euclidean distance from vishnupriya.4.1 is 0.65988827
# Euclidean distance from vishnupriya.4.2 is 0.63816494
# Euclidean distance from vishnupriya.4.10 is 0.8754146
# Euclidean distance from vishnupriya.4.7 is 0.7306407
# Euclidean distance from vishnupriya.4.8 is 0.46755758
# Euclidean distance from vishnupriya.4.3 is 0.6482854
# Euclidean distance from vishnupriya.4.4 is 0.49082565
# Euclidean distance from vishnupriya.4.5 is 0.523725
# Euclidean distance from vishnupriya.4.9 is 0.7158568
# Euclidean distance from vishnupriya.4.6 is 0.61628693
# Euclidean distance from vishnupriya.4.1 is 0.587156
# Euclidean distance from vishnupriya.4.2 is 0.5959008
# Euclidean distance from vishnupriya.4.10 is 0.7802682
# Euclidean distance from vishnupriya.4.7 is 0.81990945
# Euclidean distance from vishnupriya.4.8 is 0.57144004
# Euclidean distance from vishnupriya.4.3 is 0.68138385
# Euclidean distance from vishnupriya.4.4 is 0.56887126
# Euclidean distance from vishnupriya.4.5 is 0.6199934
# Euclidean distance from vishnupriya.4.9 is 0.81038344
# Euclidean distance from vishnupriya.4.6 is 0.75061196
# Euclidean distance from vishnupriya.4.1 is 0.67721033
# Euclidean distance from vishnupriya.4.2 is 0.607078
# Euclidean distance from vishnupriya.4.10 is 0.89522815
# Euclidean distance from vishnupriya.4.7 is 0.6833521
# Euclidean distance from vishnupriya.4.8 is 0.6081073
# Euclidean distance from vishnupriya.4.3 is 0.69523424
# Euclidean distance from vishnupriya.4.4 is 0.6748575
# Euclidean distance from vishnupriya.4.5 is 0.59827214
# Euclidean distance from vishnupriya.4.9 is 0.65210974
# Euclidean distance from vishnupriya.4.6 is 0.66005147
# Euclidean distance from vishnupriya.4.1 is 0.6951924
# Euclidean distance from vishnupriya.4.2 is 0.6083359
# Euclidean distance from vishnupriya.4.10 is 0.7713565
# Euclidean distance from vishnupriya.4.7 is 0.7370447
# Euclidean distance from vishnupriya.4.8 is 0.49880686
# Euclidean distance from vishnupriya.4.3 is 0.6352574
# Euclidean distance from vishnupriya.4.4 is 0.5101118
# Euclidean distance from vishnupriya.4.5 is 0.5191053
# Euclidean distance from vishnupriya.4.9 is 0.749788
# Euclidean distance from vishnupriya.4.6 is 0.63172305
# Euclidean distance from vishnupriya.4.1 is 0.58664083
# Euclidean distance from vishnupriya.4.2 is 0.5681412
# Euclidean distance from vishnupriya.4.10 is 0.8091707
# Euclidean distance from vishnupriya.4.7 is 0.794488
# Euclidean distance from vishnupriya.4.8 is 0.54566616
# Euclidean distance from vishnupriya.4.3 is 0.6810382
# Euclidean distance from vishnupriya.4.4 is 0.5617141
# Euclidean distance from vishnupriya.4.5 is 0.58375996
# Euclidean distance from vishnupriya.4.9 is 0.76980793
# Euclidean distance from vishnupriya.4.6 is 0.69964534
# Euclidean distance from vishnupriya.4.1 is 0.66702014
# Euclidean distance from vishnupriya.4.2 is 0.6373547
# Euclidean distance from vishnupriya.4.10 is 0.85067636
# Euclidean distance from vishnupriya.4.7 is 0.7706691
# Euclidean distance from vishnupriya.4.8 is 0.6223809
# Euclidean distance from vishnupriya.4.3 is 0.68330663
# Euclidean distance from vishnupriya.4.4 is 0.62885857
# Euclidean distance from vishnupriya.4.5 is 0.59415007
# Euclidean distance from vishnupriya.4.9 is 0.7571107
# Euclidean distance from vishnupriya.4.6 is 0.72907037
# Euclidean distance from vishnupriya.4.1 is 0.71746075
# Euclidean distance from vishnupriya.4.2 is 0.584831
# Euclidean distance from vishnupriya.4.10 is 0.8632121
# Euclidean distance from vishnupriya.4.7 is 0.799883
# Euclidean distance from vishnupriya.4.8 is 0.5255173
# Euclidean distance from vishnupriya.4.3 is 0.66149116
# Euclidean distance from vishnupriya.4.4 is 0.52557456
# Euclidean distance from vishnupriya.4.5 is 0.5677318
# Euclidean distance from vishnupriya.4.9 is 0.7772672
# Euclidean distance from vishnupriya.4.6 is 0.70749253
# Euclidean distance from vishnupriya.4.1 is 0.6249341
# Euclidean distance from vishnupriya.4.2 is 0.61644447
# Euclidean distance from vishnupriya.4.10 is 0.86004186
# Euclidean distance from vishnupriya.4.7 is 0.7141656
# Euclidean distance from vishnupriya.4.8 is 0.59314525
# Euclidean distance from vishnupriya.4.3 is 0.7403934
# Euclidean distance from vishnupriya.4.4 is 0.66102755
# Euclidean distance from vishnupriya.4.5 is 0.6120721
# Euclidean distance from vishnupriya.4.9 is 0.7073019
# Euclidean distance from vishnupriya.4.6 is 0.65285677
# Euclidean distance from vishnupriya.4.1 is 0.7017272
# Euclidean distance from vishnupriya.4.2 is 0.64305276
# Euclidean distance from vishnupriya.4.10 is 0.8027645
# Euclidean distance from vishnupriya.4.7 is 0.76495034
# Euclidean distance from vishnupriya.4.8 is 0.7405911
# Euclidean distance from vishnupriya.4.3 is 0.77300435
# Euclidean distance from vishnupriya.4.4 is 0.78296643
# Euclidean distance from vishnupriya.4.5 is 0.7050711
# Euclidean distance from vishnupriya.4.9 is 0.74755555
# Euclidean distance from vishnupriya.4.6 is 0.7501768
# Euclidean distance from vishnupriya.4.1 is 0.80246633
# Euclidean distance from vishnupriya.4.2 is 0.65593815
# Euclidean distance from vishnupriya.4.10 is 0.8546715
# Euclidean distance from vishnupriya.4.7 is 0.79355395
# Euclidean distance from vishnupriya.4.8 is 0.7276627
# Euclidean distance from vishnupriya.4.3 is 0.7227345
# Euclidean distance from vishnupriya.4.4 is 0.75209516
# Euclidean distance from vishnupriya.4.5 is 0.6732726
# Euclidean distance from vishnupriya.4.9 is 0.7599895
# Euclidean distance from vishnupriya.4.6 is 0.80151397
# Euclidean distance from vishnupriya.4.1 is 0.78480524
# Euclidean distance from vishnupriya.4.2 is 0.63856715
# Euclidean distance from vishnupriya.4.10 is 0.88808346
# Euclidean distance from vishnupriya.4.7 is 0.7092504
# Euclidean distance from vishnupriya.4.8 is 0.5959547
# Euclidean distance from vishnupriya.4.3 is 0.77189785
# Euclidean distance from vishnupriya.4.4 is 0.68723756
# Euclidean distance from vishnupriya.4.5 is 0.6388305
# Euclidean distance from vishnupriya.4.9 is 0.697554
# Euclidean distance from vishnupriya.4.6 is 0.67767483
# Euclidean distance from vishnupriya.4.1 is 0.708143
# Euclidean distance from vishnupriya.4.2 is 0.6971091
# Euclidean distance from vishnupriya.4.10 is 0.79464155
# Euclidean distance from vishnupriya.4.7 is 0.869115
# Euclidean distance from vishnupriya.4.8 is 0.6408264
# Euclidean distance from vishnupriya.4.3 is 0.74510324
# Euclidean distance from vishnupriya.4.4 is 0.6221895
# Euclidean distance from vishnupriya.4.5 is 0.65156215
# Euclidean distance from vishnupriya.4.9 is 0.8623541
# Euclidean distance from vishnupriya.4.6 is 0.7753645
# Euclidean distance from vishnupriya.4.1 is 0.7197316
# Euclidean distance from vishnupriya.4.2 is 0.6885286
# Euclidean distance from vishnupriya.4.10 is 0.9470651
# Euclidean distance from vishnupriya.4.7 is 0.8301271
# Euclidean distance from vishnupriya.4.8 is 0.63865775
# Euclidean distance from vishnupriya.4.3 is 0.7389308
# Euclidean distance from vishnupriya.4.4 is 0.6295948
# Euclidean distance from vishnupriya.4.5 is 0.648458
# Euclidean distance from vishnupriya.4.9 is 0.80559725
# Euclidean distance from vishnupriya.4.6 is 0.7626941
# Euclidean distance from vishnupriya.4.1 is 0.72908384
# Euclidean distance from vishnupriya.4.2 is 0.67312866
# Euclidean distance from vishnupriya.4.10 is 0.89946216
# Euclidean distance from vishnupriya.4.7 is 0.77504194
# Euclidean distance from vishnupriya.4.8 is 0.6615913
# Euclidean distance from vishnupriya.4.3 is 0.7600603
# Euclidean distance from vishnupriya.4.4 is 0.7017204
# Euclidean distance from vishnupriya.4.5 is 0.65684295
# Euclidean distance from vishnupriya.4.9 is 0.7304506
# Euclidean distance from vishnupriya.4.6 is 0.7451307
# Euclidean distance from vishnupriya.4.1 is 0.7460791
# Euclidean distance from vishnupriya.4.2 is 0.6984004
# Euclidean distance from vishnupriya.4.10 is 0.8459071
# Euclidean distance from vishnupriya.4.7 is 0.8085814
# Euclidean distance from vishnupriya.4.8 is 0.64301115
# Euclidean distance from vishnupriya.4.3 is 0.72225773
# Euclidean distance from vishnupriya.4.4 is 0.64890486
# Euclidean distance from vishnupriya.4.5 is 0.63812
# Euclidean distance from vishnupriya.4.9 is 0.7867388
# Euclidean distance from vishnupriya.4.6 is 0.7520267
# Euclidean distance from vishnupriya.4.1 is 0.7143863
# Euclidean distance from vishnupriya.4.2 is 0.64159054
# Euclidean distance from vishnupriya.4.10 is 0.89771
# Euclidean distance from vishnupriya.4.7 is 0.84293264
# Euclidean distance from vishnupriya.4.8 is 0.7952607
# Euclidean distance from vishnupriya.4.3 is 0.80531454
# Euclidean distance from vishnupriya.4.4 is 0.8134065
# Euclidean distance from vishnupriya.4.5 is 0.74065787
# Euclidean distance from vishnupriya.4.9 is 0.79378045
# Euclidean distance from vishnupriya.4.6 is 0.8327742
# Euclidean distance from vishnupriya.4.1 is 0.8671476
# Euclidean distance from vishnupriya.4.2 is 0.72735393
# Euclidean distance from vishnupriya.4.10 is 0.9201005
